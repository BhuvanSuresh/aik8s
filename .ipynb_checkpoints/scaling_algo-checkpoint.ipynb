# %%
from kubernetes import client, config
import time
predicted_workload=200

# Constants
NAMESPACE = "default"
DEPLOYMENT_NAME = "nginxapp"
CPU_THRESHOLD = 80
RRS = 0.1  # Remove 10% of the surplus pods in case of scaling in
POD_NAME = "nginxapp-7497954958-6zc9f"
INTERVAL = 60.0  # seconds
hpa_name = "nginxapp"


# Initialize Kubernetes client
config.load_kube_config()
app_api = client.AppsV1Api()
api=client.CoreV1Api()

hpa_api=client.AutoscalingV2Api()



# Helper function to get CPU and memory resources of a pod
def get_pod_resources():
    api_response = api.read_namespaced_pod(name=POD_NAME, namespace=NAMESPACE)
    cpu_capacity =api_response.spec.containers[0].resources.limits["cpu"]
    memory_capacity = api_response.spec.containers[0].resources.limits["memory"]
    return cpu_capacity, memory_capacity

# Function to calculate maximum workload
def calculate_max_workload():
    cpu_capacity, memory_capacity = get_pod_resources()
    cpu_cores = int(cpu_capacity[:-1])# remove the 'm' suffix
    memory_mb = int(memory_capacity[:-2])# remove the 'Mi' suffix
    cpu_utilization = 1  # assume maximum CPU utilization
    memory_usage_per_unit = 1  # assume constant memory usage per unit of workload
    max_workload_cpu = cpu_cores * cpu_utilization
    max_workload_memory = memory_mb / memory_usage_per_unit
    max_workload = min(max_workload_cpu, max_workload_memory)
    return max_workload
def pods_minimum():
    
    hpa = hpa_api.read_namespaced_horizontal_pod_autoscaler(name=hpa_name, namespace="default")
    min_replicas = hpa.spec.min_replicas
    #print(f"The minimum number of replicas for {hpa_name} is {min_replicas}")
#     api_response = app_api.read_namespaced_deployment(name=DEPLOYMENT_NAME, namespace=NAMESPACE)
#     min_replicas=api_response.spec.replicas

    return min_replicas




# Helper function to get the current number of replicas
def get_replica_count():
    deployment = app_api.read_namespaced_deployment(name=DEPLOYMENT_NAME, namespace=NAMESPACE)
    return deployment.spec.replicas

# Helper function to scale up
def scale_up(replicas):
    app_api.patch_namespaced_deployment_scale(
        name=DEPLOYMENT_NAME,
        namespace=NAMESPACE,
        body={"spec": {"replicas": replicas}}
    )
    print(f"Scaled up to {replicas} replicas")

# Helper function to scale down
def scale_down(replicas):
    api.patch_namespaced_deployment_scale(
        name=DEPLOYMENT_NAME,
        namespace=NAMESPACE,
        body={"spec": {"replicas": replicas}}
    )
    print(f"Scaled down to {replicas} replicas")

# Main loop
while True:
    max_workload_per_pod = calculate_max_workload()
    
    future_pods=predicted_workload/max_workload_per_pod
    current_pods=get_replica_count()
    if future_pods>current_pods:
        scale_up(future_pods)
    elif future_pods<current_pods:
        print(future_pods)
        print(pods_minimum)
        #future_pods=max(future_pods,pods_minimum)
        pods_surplus=(current_pods-future_pods)*RRS
        future_pods=current_pods-pods_surplus
        scale_down(future_pods)
    else:
        print("No scaling required")
    #time.sleep(INTERVAL)
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Cell In[1], line 80
#      78 # Main loop
#      79 while True:
# ---> 80     max_workload_per_pod = calculate_max_workload()
#      82     future_pods=predicted_workload/max_workload_per_pod
#      83     current_pods=get_replica_count()
#
# Cell In[1], line 33, in calculate_max_workload()
#      32 def calculate_max_workload():
# ---> 33     cpu_capacity, memory_capacity = get_pod_resources()
#      34     cpu_cores = int(cpu_capacity[:-1])# remove the 'm' suffix
#      35     memory_mb = int(memory_capacity[:-2])# remove the 'Mi' suffix
#
# Cell In[1], line 26, in get_pod_resources()
#      25 def get_pod_resources():
# ---> 26     api_response = api.read_namespaced_pod(name=POD_NAME, namespace=NAMESPACE)
#      27     cpu_capacity =api_response.spec.containers[0].resources.limits["cpu"]
#      28     memory_capacity = api_response.spec.containers[0].resources.limits["memory"]
#
# File ~/aik8s/aik8s/lib/python3.10/site-packages/kubernetes/client/api/core_v1_api.py:23483, in CoreV1Api.read_namespaced_pod(self, name, namespace, **kwargs)
#   23459 """read_namespaced_pod  # noqa: E501
#   23460
#   23461 read the specified Pod  # noqa: E501
#    (...)
#   23480          returns the request thread.
#   23481 """
#   23482 kwargs['_return_http_data_only'] = True
# > 23483 return self.read_namespaced_pod_with_http_info(name, namespace, **kwargs)
#
# File ~/aik8s/aik8s/lib/python3.10/site-packages/kubernetes/client/api/core_v1_api.py:23570, in CoreV1Api.read_namespaced_pod_with_http_info(self, name, namespace, **kwargs)
#   23567 # Authentication setting
#   23568 auth_settings = ['BearerToken']  # noqa: E501
# > 23570 return self.api_client.call_api(
#   23571     '/api/v1/namespaces/{namespace}/pods/{name}', 'GET',
#   23572     path_params,
#   23573     query_params,
#   23574     header_params,
#   23575     body=body_params,
#   23576     post_params=form_params,
#   23577     files=local_var_files,
#   23578     response_type='V1Pod',  # noqa: E501
#   23579     auth_settings=auth_settings,
#   23580     async_req=local_var_params.get('async_req'),
#   23581     _return_http_data_only=local_var_params.get('_return_http_data_only'),  # noqa: E501
#   23582     _preload_content=local_var_params.get('_preload_content', True),
#   23583     _request_timeout=local_var_params.get('_request_timeout'),
#   23584     collection_formats=collection_formats)
#
# File ~/aik8s/aik8s/lib/python3.10/site-packages/kubernetes/client/api_client.py:348, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host)
#     311 """Makes the HTTP request (synchronous) and returns deserialized data.
#     312
#     313 To make an async_req request, set the async_req parameter.
#    (...)
#     345     then the method will return the response directly.
#     346 """
#     347 if not async_req:
# --> 348     return self.__call_api(resource_path, method,
#     349                            path_params, query_params, header_params,
#     350                            body, post_params, files,
#     351                            response_type, auth_settings,
#     352                            _return_http_data_only, collection_formats,
#     353                            _preload_content, _request_timeout, _host)
#     355 return self.pool.apply_async(self.__call_api, (resource_path,
#     356                                                method, path_params,
#     357                                                query_params,
#    (...)
#     365                                                _request_timeout,
#     366                                                _host))
#
# File ~/aik8s/aik8s/lib/python3.10/site-packages/kubernetes/client/api_client.py:180, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host)
#     177     url = _host + resource_path
#     179 # perform request and return response
# --> 180 response_data = self.request(
#     181     method, url, query_params=query_params, headers=header_params,
#     182     post_params=post_params, body=body,
#     183     _preload_content=_preload_content,
#     184     _request_timeout=_request_timeout)
#     186 self.last_response = response_data
#     188 return_data = response_data
#
# File ~/aik8s/aik8s/lib/python3.10/site-packages/kubernetes/client/api_client.py:373, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     371 """Makes the HTTP request using RESTClient."""
#     372 if method == "GET":
# --> 373     return self.rest_client.GET(url,
#     374                                 query_params=query_params,
#     375                                 _preload_content=_preload_content,
#     376                                 _request_timeout=_request_timeout,
#     377                                 headers=headers)
#     378 elif method == "HEAD":
#     379     return self.rest_client.HEAD(url,
#     380                                  query_params=query_params,
#     381                                  _preload_content=_preload_content,
#     382                                  _request_timeout=_request_timeout,
#     383                                  headers=headers)
#
# File ~/aik8s/aik8s/lib/python3.10/site-packages/kubernetes/client/rest.py:241, in RESTClientObject.GET(self, url, headers, query_params, _preload_content, _request_timeout)
#     239 def GET(self, url, headers=None, query_params=None, _preload_content=True,
#     240         _request_timeout=None):
# --> 241     return self.request("GET", url,
#     242                         headers=headers,
#     243                         _preload_content=_preload_content,
#     244                         _request_timeout=_request_timeout,
#     245                         query_params=query_params)
#
# File ~/aik8s/aik8s/lib/python3.10/site-packages/kubernetes/client/rest.py:235, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     232     logger.debug("response body: %s", r.data)
#     234 if not 200 <= r.status <= 299:
# --> 235     raise ApiException(http_resp=r)
#     237 return r
#
# ApiException: (404)
# Reason: Not Found
# HTTP response headers: HTTPHeaderDict({'Audit-Id': 'a2f5db09-5d65-4e1c-9151-377791db5af1', 'Cache-Control': 'no-cache, private', 'Content-Type': 'application/json', 'X-Kubernetes-Pf-Flowschema-Uid': '614e78c6-d20d-4f93-9d52-4cfed8641fc4', 'X-Kubernetes-Pf-Prioritylevel-Uid': 'fe4bbe09-4324-46a8-ace4-77f8b132e949', 'Date': 'Tue, 18 Apr 2023 10:05:59 GMT', 'Content-Length': '218'})
# HTTP response body: {"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"pods \"nginxapp-7497954958-9qpm5\" not found","reason":"NotFound","details":{"name":"nginxapp-7497954958-9qpm5","kind":"pods"},"code":404}
